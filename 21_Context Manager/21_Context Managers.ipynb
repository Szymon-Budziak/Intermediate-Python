# %% [markdown]
# # Context Managers

# %% [markdown]
# ### Context manager in opening a file

# %%
file = open('notes2.txt', 'w')
try:
    file.write('some todoo...')
finally:
    file.close()

# %%
# better way to do it
with open('notes.txt', 'w') as file:
    file.write('some todoo...')

# %% [markdown]
# ### Context manager in lock

# %%
from threading import Lock
lock = Lock()
lock.acquire()
#....
lock.release()

# %%
# better way to do it
lock = Lock()
with lock:
    print('do something')
    #...
# Out:
# do something

# %% [markdown]
# ### Context manager for our own classes

# %%
class ManagedFile:
    def __init__(self, filename):
        print('init')
        self.filename = filename
        
    def __enter__(self):
        print('enter')
        self.file = open(self.filename, 'w')
        return self.file
    
    def __exit__(self, exc_type, exc_value, exc_traceback):
        if self.file:
            self.file.close()
        print('exit')
        
with ManagedFile('notes3.txt') as file:
    print('do some stuff...')
    file.write('some todoo...')
# Out:
# init
# enter
# do some stuff...
# exit

# %%
class ManagedFile:
    def __init__(self, filename):
        print('init')
        self.filename = filename
        
    def __enter__(self):
        print('enter')
        self.file = open(self.filename, 'w')
        return self.file
    
    def __exit__(self, exc_type, exc_value, exc_traceback):
        if self.file:
            self.file.close()
        print('exc:', exc_type, exc_value)
        print('exit')
        
with ManagedFile('notes3.txt') as file:
    print('do some stuff...')
    file.write('some todoo...')
print('continuing')
# Out:
# init
# enter
# do some stuff...
# exc: None None
# exit
# continuing

# %%
class ManagedFile:
    def __init__(self, filename):
        print('init')
        self.filename = filename
        
    def __enter__(self):
        print('enter')
        self.file = open(self.filename, 'w')
        return self.file
    
    def __exit__(self, exc_type, exc_value, exc_traceback):
        if self.file:
            self.file.close()
        print('exc:', exc_type, exc_value)
        print('exit')
        
with ManagedFile('notes3.txt') as file:
    print('do some stuff...')
    file.write('some todoo...')
    file.somemethod() # there is no such a function so it raises and exception
print('continuing') # we won't reach this continuing
# Out:
# init
# enter
# do some stuff...
# exc: <class 'AttributeError'> '_io.TextIOWrapper' object has no attribute 'somemethod'
# exit
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-7-04f6985ac39e> in <module>
#      18     print('do some stuff...')
#      19     file.write('some todoo...')
# ---> 20     file.somemethod() # there is no such a function so it raises and exception
#      21 print('continuing') # we won't reach this continuing
#
# AttributeError: '_io.TextIOWrapper' object has no attribute 'somemethod'

# %%
# handling exception by ourselves
class ManagedFile:
    def __init__(self, filename):
        print('init')
        self.filename = filename
        
    def __enter__(self):
        print('enter')
        self.file = open(self.filename, 'w')
        return self.file
    
    def __exit__(self, exc_type, exc_value, exc_traceback):
        if self.file:
            self.file.close()
        if exc_type is not None:
            print('exception has beem handled')
        print('exit')
        return True
        
with ManagedFile('notes3.txt') as file:
    print('do some stuff...')
    file.write('some todoo...')
    file.somemethod()
print('continuing')
# Out:
# init
# enter
# do some stuff...
# exception has beem handled
# exit
# continuing

# %% [markdown]
# ### Context manager implemented as a function

# %%
from contextlib import contextmanager

# %%
@contextmanager
def open_managed_file(filename):
    f = open(filename, 'w')
    try:
        yield f
    finally:
        f.close()

with open_managed_file('notes4.txt') as f:
    f.write('some todoo...')
